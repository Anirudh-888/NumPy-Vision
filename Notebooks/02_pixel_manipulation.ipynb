# %% [markdown]
# ## Modifying a Pixel
#
# A NumPy array can be modified directly using **indexing**.
#
# *For an RGB image, the first two dimensions identify the pixel's location:*
#
# ```text
# (row, column)

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [

        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The color in the location before",rgb_image[1,1])
plt.imshow(rgb_image)
plt.show()
rgb_image[1,1]=[255,255,0]
print("The color in the location after changing",rgb_image[1,1])
plt.imshow(rgb_image)
# Out:
# The color in the location before [0 0 0]
# The color in the location after changing [255 255   0]

# %% [markdown]
# # Project Task: Image Cropping
#
# ## What I Built
#
# In this step, I built a basic **image cropping operation** using NumPy array slicing.
#
# I extracted a smaller rectangular region from my original RGB image while preserving the RGB values of each selected pixel.
#
# ## Concept I Used
#
# ### NumPy Array Slicing
#
# I used **NumPy array slicing** to select a range of rows and columns from my multidimensional image array.
#
# The general slicing syntax is:
#
# ```text
# start : stop

# %% [markdown]
# ## Cropped the image as 2*2

# %%
import numpy as np
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image\n",rgb_image)
cropped_image=rgb_image[0:2,0:2,0:3]
print("The cropped image is\n",cropped_image)
display(np.shape(cropped_image))
display(cropped_image.ndim)
display(np.size(cropped_image))
# Out:
# The original image
#  [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [255   0   0]]
#
#  [[  0 255   0]
#   [  0   0 255]
#   [  0   0   0]]]
# The cropped image is
#  [[[255   0   0]
#   [  0 255   0]]
#
#  [[255 255 255]
#   [  0   0   0]]]
# (2, 2, 3)
# 3
# 12

# %% [markdown]
# ## Cropping only the second row

# %%
import numpy as np
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image\n",rgb_image)
cropped_image=rgb_image[1:2,0:3,0:3]
print("The cropped image is\n",cropped_image)
display(np.shape(cropped_image))
display(cropped_image.ndim)
display(np.size(cropped_image))
# Out:
# The original image
#  [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [255   0   0]]
#
#  [[  0 255   0]
#   [  0   0 255]
#   [  0   0   0]]]
# The cropped image is
#  [[[255 255 255]
#   [  0   0   0]
#   [255   0   0]]]
# (1, 3, 3)
# 3
# 9

# %% [markdown]
# ## Cropping the 2nd and the 3rd Column

# %%
import numpy as np
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image\n",rgb_image)
cropped_image=rgb_image[1:3,0:3,0:3]
print("The cropped image\n",cropped_image)
print("The shape of the cropped image:",np.shape(cropped_image))
print("The dimension of the cropped image:",(cropped_image.ndim))
print("The size of the cropped image:",display(np.size(cropped_image)))
# Out:
# The original image
#  [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [255   0   0]]
#
#  [[  0 255   0]
#   [  0   0 255]
#   [  0   0   0]]]
# The cropped image
#  [[[  0 255   0]
#   [  0   0 255]]
#
#  [[  0   0   0]
#   [255   0   0]]
#
#  [[  0   0 255]
#   [  0   0   0]]]
# The shape of the cropped image: (3, 2, 3)
# The dimension of the cropped image: 3
# The size of the cropped image: 18

# %% [markdown]
# # Project Task: Image Visualization
#
# ## What I Built
#
# In this step, I visualized my RGB NumPy array as an actual image instead of viewing it only as numerical RGB values.
#
# ## Concept I Used
#
# ### Image Visualization with Matplotlib
#
# I used **Matplotlib** to display the image represented by my NumPy array.
#
# My image is stored as a 3D NumPy array with the structure:
#
# ```text
# (height, width, channels)

# %%
import numpy as np 
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
plt.imshow(rgb_image)
plt.show()

# %% [markdown]
# # Accessing Regions of an Image Using NumPy Slicing
#
# After exploring individual pixels and RGB channel values, I extended the same indexing concept to access larger regions of the image.
#
# Since an RGB image is represented as a three-dimensional NumPy array with the structure:
#
# `(height, width, channels)`
#
# I can use NumPy slicing to select a rectangular region of the image.
#
# ## Key Concept
#
# A region of an image can be accessed using:
#
# `image[start_row:end_row, start_column:end_column]`
#
# When the channel axis is not specified, NumPy preserves all the RGB channel values for the selected region.
#
# I can also explicitly represent the complete structure as:
#
# `image[start_row:end_row, start_column:end_column, :]`
#
# Here, `:` means that all color channels are included.
#
# ## Why This Matters
#
# Image slicing allows me to work with specific regions instead of processing the entire image. This concept is essential for image cropping, region-based pixel manipulation, image preprocessing, and computer vision applications.

# %% [markdown]
# # Applying NumPy Slicing to a Real Image
#
# In this section, I applied NumPy slicing to a real RGB image to select a specific rectangular region.
#
# After understanding slicing with manually created arrays, working with a real image helped me connect the same concept to actual pixel data. By selecting specific ranges of rows and columns, I can isolate different areas of the image while preserving their RGB information.
#
# This demonstrates how NumPy slicing can be used in practical image-processing tasks such as region selection, cropping, and localized pixel manipulation.

# %% [markdown]
# # Selecting a Region from a Real Image
#
# In this section, I applied NumPy slicing to select and visualize a specific region of the real motorcycle image.
#
# By selecting a range of rows and columns, I can isolate a rectangular portion of the image. The RGB channel information is preserved, allowing the selected region to remain a complete color image.
#
# This demonstrates how the same NumPy slicing concepts used with small arrays can be directly applied to real-world image data.

# %%
import numpy as np
import matplotlib.pyplot as plt
image=plt.imread("../Images/Input/motorcycle_original.png")
image_region=image[400:800,400:800]
print("The cropped region from the image : The bike in the image is")
plt.imshow(image_region)
plt.show()
# Out:
# The cropped region from the image : The bike in the image is

# %% [markdown]
# # Modifying a Region of a Real Image
#
# In this section, I applied NumPy array assignment to modify a specific region of a real image.
#
# After selecting a rectangular region using slicing, I can change the pixel values within that region. Since an image is represented as numerical data, modifying those values directly changes the visual appearance of the image.
#
# To preserve the original image, I will perform modifications on a copy of the image. This allows me to compare the original image with the modified result without permanently changing the original array.
#
# This demonstrates how NumPy can be used for localized image editing and forms the foundation for more advanced image-processing operations.

# %%
import numpy as np
import matplotlib.pyplot as plt
image=plt.imread("../Images/Input/motorcycle_original.png")
modified_image=image.copy()
modified_image[400:800,400:800]=[0.365,0.352,0.145]
plt.imshow(modified_image)
plt.show()

# %% [markdown]
# # Modifying Individual Color Channels
#
# In this section, I applied NumPy indexing and slicing to manipulate individual RGB channels within a selected region of a real image.
#
# Instead of replacing all three color values of each pixel, I can target a specific channel using the third axis of the image array.
#
# For an RGB image:
#
# - Channel 0 represents Red
# - Channel 1 represents Green
# - Channel 2 represents Blue
#
# By modifying only one channel, I can change a specific component of the color information while preserving the remaining channels.
#
# This demonstrates how the three-dimensional structure of an image can be used for more precise pixel-level and region-based image manipulation.

# %%
import numpy as np
import matplotlib.pyplot as plt
image_path="../Images/Input/motorcycle_original.png"
image=plt.imread(image_path)
image_region=image.copy()
image_region[400:700,400:700,0]=0.0
image_region[0:200,0:200,1]=0.0
image_region[800:1000,800:1000,2]=0.0
print("The image after removing individual RGB channels from selected regions")
plt.imshow(image_region)
plt.show()
# Out:
# The image after removing red green and blue in some regions
