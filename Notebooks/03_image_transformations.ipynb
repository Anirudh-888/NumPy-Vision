# %% [markdown]
# # Step 7: Image Transformations
#
# ## What I am doing
#
# In this step, I am applying **image transformations** to manipulate the position and orientation of pixels in my image.
#
# ## Concept I am using
#
# I am using **NumPy array manipulation** to transform an image by changing the arrangement of its rows and columns while keeping the RGB values of each pixel intact.
#
# ### Transformations I will learn
#
# - **Flipping** — reversing the order of pixels along an axis.
# - **Rotating** — changing the orientation of the image by rearranging its dimensions.
# - **Transposing** — interchanging the rows and columns of an array.
#
# ## What I am learning
#
# I am learning how operations on a NumPy array directly affect the spatial arrangement of pixels in an image.
#
# This helps me understand how NumPy can be used for practical image processing and forms a foundation for later computer vision operations.

# %% [markdown]
# ### Flipping the image

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image is")
display(plt.imshow(rgb_image))
plt.show()
print("Flipping the image")
flipped_image=rgb_image[:,::-1,:]
plt.imshow(flipped_image)
plt.show()
# Out:
# The original image is
# Flipping the image

# %% [markdown]
# # Vertical Image Flipping
#
# ## What I am doing
#
# In this step, I am performing a **vertical flip** on an RGB image using NumPy array slicing.
#
# ## Concept I am using
#
# An RGB image is represented as a three-dimensional NumPy array with the structure:
#
# `(rows, columns, RGB channels)`
#
# To flip an image vertically, I need to reverse the order of the **rows** while keeping the columns and RGB channels unchanged.
#
# ## What changes
#
# - Rows → Reversed
# - Columns → Unchanged
# - RGB channels → Unchanged
#
# ## What I learned
#
# I learned that image transformations can be performed by manipulating specific axes of a NumPy array. By reversing the row axis, I can flip an image vertically without changing its dimensions or pixel color values.

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image is")
plt.imshow(rgb_image)
plt.show()
print("Performing vertical flip")
vertically_Flipped_Image=rgb_image[::-1,:,:]
plt.imshow(vertically_Flipped_Image)
plt.show()
# Out:
# The original image is
# Performing vertical flip

# %% [markdown]
# # Image Rotation
#
# ## What I am doing
#
# In this step, I am rotating an RGB image to change its orientation while preserving the color information of every pixel.
#
# ## Concept I am using
#
# I am using NumPy array manipulation to rearrange the spatial positions of pixels in an image. Image rotation changes the relationship between the row and column positions of pixels.
#
# ## What I will understand
#
# Through this operation, I will learn how rows and columns are rearranged when an image is rotated and how NumPy can perform these transformations efficiently.
#
# ## Why this is important
#
# Image rotation is an important image transformation used in computer vision and machine learning. Understanding how pixel positions change helps build intuition for image preprocessing and data augmentation.

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])

# %% [markdown]
# # 90° Clockwise Image Rotation
#
# ## What I am doing
#
# In this step, I am rotating an RGB image by **90 degrees clockwise** using NumPy array transformations.
#
# ## Concepts I am using
#
# I am combining my understanding of **transpose** and **flipping** to rearrange the spatial positions of pixels in the image.
#
# A rotation changes the positions of rows and columns while preserving the RGB values of each pixel.
#
# ## How I am thinking about rotation
#
# Instead of manually moving every pixel to a new position, I can perform image rotation by combining array operations such as transposing and flipping.
#
# ## Why this is important
#
# Understanding image rotation helps me learn how NumPy can manipulate image data efficiently. These transformations are also useful in computer vision and machine learning for image preprocessing and data augmentation.

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image")
plt.imshow(rgb_image)
plt.show()
transposed_image=np.transpose(rgb_image,axes=(1,0,2))
plt.imshow(transposed_image)
plt.show()
flipped_image=np.flip(transposed_image,axis=1)
print("The completely rotated image is")
plt.imshow(flipped_image)
plt.show()
# Out:
# The original image
# The completely rotated image is

# %% [markdown]
# # 90° Counterclockwise Image Rotation
#
# ## What I am doing
#
# In this step, I am rotating an RGB image by **90 degrees counterclockwise** using NumPy array transformations.
#
# ## Concepts I am using
#
# I am combining **array transposition** and **array flipping** to rearrange the positions of pixels in the image.
#
# ## How the rotation works
#
# First, I transpose the image to swap its spatial dimensions:
#
# - Rows become columns
# - Columns become rows
# - RGB channels remain unchanged
#
# After transposing the image, I flip the **rows (axis 0)** to produce a 90° counterclockwise rotation.
#
# ## Transformation Process
#
# Original Image
# ↓
# Transpose
# ↓
# Flip Rows (Axis 0)
# ↓
# 90° Counterclockwise Rotation
#
# ## What I learned
#
# I learned that different image rotations can be created by combining NumPy operations. A 90° clockwise rotation and a 90° counterclockwise rotation both use transposition, but they differ in the axis that is flipped afterward.

# %%
import numpy as np 
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The orginal image is")
plt.imshow(rgb_image)
plt.show()
transposed_image=np.transpose(rgb_image, axes=(1,0,2))
counter_clock_wise_flipped_image=np.flip(transposed_image,axis=(0))
print("The counter clock wise flipped image")
plt.imshow(counter_clock_wise_flipped_image)
plt.show()
# Out:
# The orginal image is
# The counter clock wise flipped image

# %% [markdown]
# # 180° Image Rotation
#
# ## What I am doing
#
# In this step, I am rotating an RGB image by **180 degrees** using NumPy array manipulation.
#
# ## Concepts I am using
#
# I am using my understanding of array axes and flipping to rearrange the positions of pixels in the image.
#
# A 180-degree rotation reverses the image both vertically and horizontally.
#
# ## How the rotation works
#
# To rotate an image by 180 degrees, I need to reverse:
#
# - The rows
# - The columns
#
# The RGB channels remain unchanged because the color information of each pixel should not be modified.
#
# ## Transformation Process
#
# Original Image
# ↓
# Reverse Rows (Axis 0)
# ↓
# Reverse Columns (Axis 1)
# ↓
# 180° Rotated Image
#
# ## What I learned
#
# I learned that a complex-looking image transformation can be performed by manipulating the appropriate axes of a NumPy array. By reversing both spatial axes, I can rotate an image by 180 degrees while preserving its RGB color information.

# %%
import numpy as np
import matplotlib.pyplot as plt
rgb_image=np.array([
    [
        [255,0,0],
        [0,255,0],
        [0,0,255]        
    ],
    [
        [255,255,255],
        [0,0,0],
        [255,0,0]
    ],
    [
        [0,255,0],
        [0,0,255],
        [0,0,0]        
    ]
])
print("The original image is")
plt.imshow(rgb_image)
plt.show()
image_180_flipped=np.flip(rgb_image,axis=(0,1))
print("The 180 flipped image is")
plt.imshow(image_180_flipped)
plt.show()
# Out:
# The original image is
# The 180 flipped image is

# %% [markdown]
# # Applying Image Transformations to a Real Image
#
# In this notebook, I apply the image transformation concepts I previously practiced using a small RGB array to a real motorcycle image.
#
# The focus of this notebook is on observing how transformations such as flipping, transposing, and rotating affect the spatial arrangement of pixels in a real image.
#
# Using NumPy operations, I will transform the motorcycle image while preserving its underlying pixel data and observe the visual results of each transformation.

# %% [markdown]
# # Horizontal Flip of a Real Image
#
# In this section, I applied a horizontal flip to the motorcycle image using NumPy.
#
# The transformation reverses the spatial arrangement of pixels from left to right while preserving the pixel values themselves. This allows me to observe how the same NumPy transformation behaves when applied to a real image.

# %%
import numpy as np
import matplotlib.pyplot as plt
image_path="../Images/Input/motorcycle_original.png"
image=plt.imread(image_path)
flipped_image=image.copy()
flipped_image=flipped_image[:,::-1,:]
print("The original image")
plt.imshow(image)
plt.show()
print("The horizontally flipped image")
plt.imshow(flipped_image)
plt.show()
# Out:
# The original image
# The horizontally flipped image

# %% [markdown]
# # Vertical Flip of a Real Image
#
# In this section, I applied a vertical flip to the motorcycle image using NumPy.
#
# The transformation reverses the spatial arrangement of pixels from top to bottom while preserving the pixel values themselves. This allows me to observe how vertical flipping changes the orientation of a real image without modifying its underlying color information.

# %%
import numpy as np
import matplotlib.pyplot as plt
image=plt.imread(image_path)
vertically_Flipped_Image=image.copy()
vertically_Flipped_Image=vertically_Flipped_Image[::-1,:,:]
print("The original image")
plt.imshow(image)
plt.show()
print("The vertically flipped image")
plt.imshow(vertically_Flipped_Image)
plt.show()
# Out:
# The original image
# The vertically flipped image

# %% [markdown]
# # Transposing a Real Image
#
# In this section, I applied a transpose operation to the motorcycle image using NumPy.
#
# The motorcycle image is represented using three dimensions: height, width, and color channels. By transposing the spatial dimensions of the image, I swap its rows and columns while keeping the RGB channel dimension unchanged.
#
# This transformation changes the spatial arrangement of the image by exchanging its height and width dimensions.

# %%
import numpy as np 
import matplotlib.pyplot as plt
image=plt.imread(image_path)
transposed_image=np.transpose(image,axes=(1,0,2))
print("The original image")
plt.imshow(image)
plt.show()
print("The transposed image")
plt.imshow(transposed_image)
plt.show()
# Out:
# The original image
# The transposed image

# %% [markdown]
# # Rotating a Real Image by 90° Clockwise
#
# In this section, I applied a 90° clockwise rotation to the motorcycle image using the NumPy transformation concepts I previously learned.
#
# The rotation is performed by first transposing the spatial dimensions of the image and then flipping the appropriate axis. This changes the positions of the pixels while preserving their underlying RGB values.
#
# By combining multiple NumPy operations, I can perform a complete geometric transformation on a real image.

# %%
import numpy as np
import matplotlib.pyplot as plt 
image=plt.imread(image_path)
clock_wise_flipped_image=np.transpose(image,axes=(1,0,2))
clock_wise_flipped_image=np.flip(clock_wise_flipped_image,axis=1)
print("The original image")
plt.imshow(image)
plt.show()
print("The clockwise flipped image")
plt.imshow(clock_wise_flipped_image)
plt.show()
# Out:
# The original image
# The clockwise flipped image

# %% [markdown]
# # Rotating a Real Image by 90° Counterclockwise
#
# In this section, I applied a 90° counterclockwise rotation to the motorcycle image using NumPy.
#
# The rotation is performed by first transposing the spatial dimensions of the image and then flipping the appropriate axis. By combining these operations, the pixels are repositioned to produce a 90° counterclockwise rotation while preserving their original RGB values.
#
# This demonstrates how multiple NumPy array operations can be combined to perform geometric transformations on a real image.

# %%
import numpy as np 
import matplotlib.pyplot as plt
image=plt.imread(image_path)
transposed_image=np.transpose(image,axes=(1,0,2))
counter_clock_wise_flipped_image=np.flip(transposed_image,axis=0)
print("The original image")
plt.imshow(image)
plt.show()
print("The transposed image")
plt.imshow(transposed_image)
plt.show()
# Out:
# The original image
# The transposed image

# %% [markdown]
# # Rotating a Real Image by 180°
#
# In this section, I applied a 180° rotation to the motorcycle image using NumPy.
#
# A 180° rotation changes the spatial arrangement of the image by reversing both its vertical and horizontal directions. The pixel values and RGB color information remain unchanged, but their positions are rearranged.
#
# By applying the appropriate NumPy transformation, I can rotate the complete motorcycle image by 180° and observe how the spatial orientation of the image changes.

# %%
import numpy as np
import matplotlib.pyplot as plt
image=plt.imread(image_path)
image_180_flipped=np.flip(image,axis=(0,1))
print("The original image")
plt.imshow(image)
plt.show()
print("The flipped image")
plt.imshow(image_180_flipped)
plt.show()
# Out:
# The original image
# The flipped image

# %% [markdown]
# # Adjusting Image Contrast
#
# Contrast refers to the difference in intensity between the darker and brighter regions of an image.
#
# Increasing contrast makes dark pixels darker and bright pixels brighter, creating a stronger visual difference.
#
# Decreasing contrast makes pixel intensities move closer together, producing a flatter-looking image.
#
# ## Contrast Adjustment
#
# Unlike brightness adjustment, contrast adjustment changes pixel values relative to a reference point.
#
# For an image whose pixel values are normalized between `0` and `1`, the midpoint can be considered as:
#
# ```text
# 0.5

# %%
import numpy as np 
import matplotlib.pyplot as plt 
image_path="../Images/Input/motorcycle_original.png"
original_image=plt.imread(image_path)
print("The original image")
plt.imshow(original_image)
plt.show()
midpoint=0.5
contrast_factor=float(input("Enter the contrast factor to increase or decrease the contrast of the image"))
new_image=np.clip((original_image-midpoint)*contrast_factor+midpoint,0,1)
print("The image after changing the contrast")
plt.imshow(new_image)
plt.show()
# Out:
# The original image
# The image after changing the contrast

# %% [markdown]
# # Increasing the Contrast of an Image
#
# Increasing contrast increases the difference between darker and brighter pixel values.
#
# Dark pixels become relatively darker, while bright pixels become relatively brighter. This makes the image appear more visually distinct and vivid.
#
# For a normalized image with pixel values between `0` and `1`, a midpoint of `0.5` can be used as the reference intensity.
#
# The contrast adjustment formula is:
#
# ```text
# new_image = (image - midpoint) × contrast_factor + midpoint
#
# contrast_factor > 1

# %%
import numpy as np 
import matplotlib.pyplot as plt 
image_path="../Images/Input/motorcycle_original.png"
original_image=plt.imread(image_path)
print("The original image")
plt.imshow(original_image)
plt.show()
midpoint=0.5
contrast_factor=3
new_image=np.clip((original_image-midpoint)*contrast_factor+midpoint,0,1)
print("The image after changing the contrast")
plt.imshow(new_image)
plt.show()
# Out:
# The original image
# The image after changing the contrast

# %% [markdown]
# # Decreasing the Contrast of an Image
#
# Decreasing contrast reduces the difference between darker and brighter pixel values.
#
# Dark and bright pixels move closer to the reference intensity, making the image appear flatter and less visually distinct.
#
# For a normalized image with pixel values between `0` and `1`, a midpoint of `0.5` can be used as the reference intensity.
#
# The contrast adjustment formula is:
#
# ```text
# new_image = (image - midpoint) × contrast_factor + midpoint
# 0 < contrast_factor < 1

# %%
import numpy as np
import matplotlib.pyplot as plt
image_path="../Images/Input/motorcycle_original.png"
original_image=plt.imread(image_path)
print("The original image")
plt.imshow(original_image)
plt.show()
contrast_factor=0.3
midpoint=0.5
new_image=np.clip((original_image-midpoint)*contrast_factor+midpoint,0,1)
print("The image after decreasing the contrast")
plt.imshow(new_image)
plt.show()
# Out:
# The original image
# The image after decreasing the contrast
